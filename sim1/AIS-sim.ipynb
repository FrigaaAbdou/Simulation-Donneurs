# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Charger le fichier Excel et la feuille RET+FERR
file_path = "Tout.xlsx"
df = pd.read_excel(file_path, sheet_name="RET+FERR")

# Nettoyage des données
df_cleaned = df.iloc[1:].reset_index(drop=True)
df_cleaned.columns = [
    "ID", "Sexe", "RBC", "HGB", "HCT", "MCV", "MCHC", "MCH", "Ferritine",
    "Carence_Martiale", "Absence_Iron_Stocks", "Low_Iron_Stocks", "Anemie",
    "Ret_Hb", "Statut_Don", "RDW_SD", "RDW_CV", "IRF", "HFR"
]
df_cleaned = df_cleaned[["ID", "Sexe", "MCV", "MCHC", "MCH", "Ret_Hb", "RDW_CV", "Ferritine"]]

# Convertir en valeurs numériques
df_cleaned[["MCV", "MCHC", "MCH", "Ret_Hb", "RDW_CV", "Ferritine"]] = df_cleaned[["MCV", "MCHC", "MCH", "Ret_Hb", "RDW_CV", "Ferritine"]].apply(pd.to_numeric, errors='coerce')
df_cleaned = df_cleaned.dropna().reset_index(drop=True)

# Appliquer le nouvel algorithme AIS
def detect_ais(rdw_cv, mch, mchc):
    if (rdw_cv < 13.25) or (rdw_cv > 13.25 and mch > 26.95 and mchc > 32.5):
        return "AIS Excluded"
    elif (rdw_cv > 13.25 and mch < 26.95) or (rdw_cv > 13.25 and mch > 26.95 and mchc < 32.5):
        return "AIS Probable"
    else:
        return "Indeterminate"

df_cleaned["Statut_AIS"] = df_cleaned.apply(lambda row: detect_ais(row["RDW_CV"], row["MCH"], row["MCHC"]), axis=1)

# Afficher les données nettoyées
display(df_cleaned.head(20))  
df_cleaned.to_excel("resultats_AIS.xlsx", index=False)

# Graphique amélioré : Répartition des donneurs par statut AIS
distribution_ais = df_cleaned["Statut_AIS"].value_counts()
plt.figure(figsize=(12, 7))
bars = distribution_ais.plot(kind='bar', color=['cornflowerblue', 'tomato', 'gray'])
plt.title("Répartition des donneurs selon le statut AIS", fontsize=16, fontweight='bold')
plt.ylabel("Nombre de donneurs", fontsize=14)
plt.xlabel("Statut AIS", fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Ajouter des valeurs sur les barres
for bar in bars.patches:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5, str(int(bar.get_height())), ha='center', fontsize=14, fontweight='bold', color='black')

plt.tight_layout()
plt.show()
# Out:
#              ID Sexe   MCV  MCHC   MCH  Ret_Hb  RDW_CV  Ferritine  \
# 0   16012417517    M  84.3  35.8  30.2    34.7    12.3      97.21
# 1   16012417518    F  83.8  33.4  28.0    32.3    13.4     184.20
# 2   16012417519    F  85.8  36.0  30.9    34.9    12.1     220.80
# 3   16012417521    M  85.6  35.7  30.6    35.1    12.9     336.00
# 4   16012417522    M  85.8  33.0  28.3    32.5    13.2      53.75
# 5   16012417524    M  83.9  32.4  27.2    31.9    12.5      41.55
# 6   16012417528    M  85.1  34.7  29.5    34.5    12.9      68.75
# 7   16012417529    M  85.6  35.5  30.4    35.2    12.3      45.42
# 8   16012417530    M  80.2  34.7  27.8    31.9    11.9     145.00
# 9   16012417531    M  81.8  36.5  29.9    33.8    12.9     230.70
# 10  16012417532    M  81.2  35.6  28.9    33.5    11.8     386.90
# 11  16012417533    M  78.6  35.4  27.8    33.1    12.0      59.29
# 12  16012417534    M  84.3  33.6  28.3    32.2    13.2      77.36
# 13  16012417535    M  81.1  35.7  28.9    33.6    12.6     141.30
# 14  16012417536    M  90.4  34.5  31.2    36.0    14.2     148.10
# 15  16012417537    M  82.5  34.6  28.5    34.1    13.2     141.50
# 16  16012417538    M  86.8  34.9  30.3    35.5    12.8     103.90
# 17  16012417539    M  83.7  34.1  28.5    32.8    12.9      72.40
# 18  16012417540    F  82.5  34.4  28.4    32.8    12.8     139.90
# 19  16012417541    M  79.0  34.1  26.9    31.6    12.3     131.60
#
#                                            Statut_AIS
# 0   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 1   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 2   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 3   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 4   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 5   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 6   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 7   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 8   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 9   AIS Excluded (Sensitivity 91,5% - Specificity ...
# 10  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 11  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 12  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 13  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 14  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 15  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 16  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 17  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 18  AIS Excluded (Sensitivity 91,5% - Specificity ...
# 19  AIS Excluded (Sensitivity 91,5% - Specificity ...
